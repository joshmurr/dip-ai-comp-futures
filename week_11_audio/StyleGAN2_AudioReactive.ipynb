# %% [markdown]
# #StyleGAN2 Reactive Audio
#
# Original Text:
# > By Derrick Schultz
#
# > This notebook shows one basic example of how to alter your StyleGAN2 vectors with audio. There are lots of different techniques to explore in this, but this is one simple way.
#
# > Big thanks to Robert Luxemburg who provided the basis for a lot of this code with [this gist](https://gist.github.com/rolux/48f1da6cf2bc6ca5833dbacbf852b348)

# %% [markdown]
# ##Installation
#
# First let’s install the repos and dependencies needed.
#
# **You may get asked to restart the runtime after running this cell. That's fine, there should be a button appear at the end of the output you can just click on. After that run the cell again to be safe and then continue.**

# %%
# %tensorflow_version 1.x

# Derrick's repo (even if you trained with skyflynil this will work!)
# !git clone https://github.com/dvschultz/stylegan2.git #use this fork to get interpolation functions
# !pip install opensimplex # needed for noise interpolation
# %cd stylegan2
# Out:
# TensorFlow 1.x selected.
# fatal: destination path 'stylegan2' already exists and is not an empty directory.
# Requirement already satisfied: opensimplex in /usr/local/lib/python3.7/dist-packages (0.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from opensimplex) (1.21.5)
# /content/stylegan2

# %%
# !gdown --id 1UlDmJVLLnBD9SnLSMXeiZRO6g-OMQCA_ -O /content/ffhq.pkl
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UlDmJVLLnBD9SnLSMXeiZRO6g-OMQCA_
# To: /content/ffhq.pkl
# 100% 382M/382M [00:02<00:00, 138MB/s]

# %% [markdown]
# ## Upload an audio file
#
# I recommend uploading something simple to start with (think a single instrument or track with silence in it). The file should be in .mp3 or .wav format - but I recommend .wav as it won't _always_ work with .mp3.
#
# The length of audio sets the duration of the video produced, so I also recommend using a shorter click to start with to make sure everything works.

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-006b4e86-dcc7-4d0a-bbfc-80806b494fa2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-006b4e86-dcc7-4d0a-bbfc-80806b494fa2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving one-man-clap.wav to one-man-clap.wav

# %% [markdown]
# ##Process audio
# The next step process our audio files. Edit the first line of the next cell to point to your audio file. The run the cell after that to process the audio and generate a graph of the volume data.
#
# Remember an easy way to do this is to locate the uploaded file, right-click on it and click `Copy Path`, you can then just paste that inside the quotation marks for the variable `filename` below.

# %%
filename = '/content/stylegan2/one-man-clap.wav'
fps = 60

# %%
import os
import numpy as np
from scipy.interpolate import interp1d
from scipy.io import wavfile
import matplotlib.pyplot as plt
import PIL.Image
import moviepy.editor

import dnnlib
import dnnlib.tflib as tflib
import pretrained_networks

audio = {}

if not os.path.exists(filename):
    audio_clip = moviepy.editor.AudioFileClip(filename)
    audio_clip.write_audiofile(filename, fps=44100, nbytes=2, codec='pcm_s16le')
track_name = os.path.basename(filename)[:-4]
rate, signal = wavfile.read(filename)
signal = np.mean(signal, axis=1) # to mono
signal = np.abs(signal)
# seed = signal.shape[0]
duration = signal.shape[0] / rate
frames = int(np.ceil(duration * fps))
samples_per_frame = signal.shape[0] / frames
audio[track_name] = np.zeros(frames, dtype=signal.dtype)
for frame in range(frames):
    start = int(round(frame * samples_per_frame))
    stop = int(round((frame + 1) * samples_per_frame))
    audio[track_name][frame] = np.mean(signal[start:stop], axis=0)
audio[track_name] /= max(audio[track_name])

for track in sorted(audio.keys()):
    plt.figure(figsize=(8, 3))
    plt.title(track)
    plt.plot(audio[track])
    plt.savefig(f'../{track}.png')

# %% [markdown]
# Run the next cell to define some functions we’ll need to use to generate our inference images.

# %%
import random
def generate_zs_from_seeds(seeds,Gs):
    zs = []
    for seed_idx, seed in enumerate(seeds):
        rnd = np.random.RandomState(seed)
        z = rnd.randn(1, *Gs.input_shape[1:]) # [minibatch, component]
        zs.append(z)
    return zs

def convertZtoW(latent, truncation_psi=0.7, truncation_cutoff=9):
  dlatent = Gs.components.mapping.run(latent, None) # [seed, layer, component]
  dlatent_avg = Gs.get_var('dlatent_avg') # [component]
  for i in range(truncation_cutoff):
    dlatent[0][i] = (dlatent[0][i]-dlatent_avg)*truncation_psi + dlatent_avg
    
  return dlatent

def generate_images_in_w_space(dlatents, truncation_psi,folder='random'):
    Gs_kwargs = dnnlib.EasyDict()
    Gs_kwargs.output_transform = dict(func=tflib.convert_images_to_uint8, nchw_to_nhwc=True)
    Gs_kwargs.randomize_noise = False
    Gs_kwargs.truncation_psi = truncation_psi
    dlatent_avg = Gs.get_var('dlatent_avg') # [component]

    if folder == 'random':
      temp_dir = 'frames%06d'%int(1000000*random.random())
    else:
      temp_dir = folder
    os.system('mkdir %s'%temp_dir)

    for row, dlatent in enumerate(dlatents):
        print('Generating image for step %d/%d ...' % (row, len(dlatents)))
        #row_dlatents = (dlatent[np.newaxis] - dlatent_avg) * np.reshape(truncation_psi, [-1, 1, 1]) + dlatent_avg
        dl = (dlatent-dlatent_avg)*truncation_psi   + dlatent_avg
        row_images = Gs.components.synthesis.run(dlatent,  **Gs_kwargs)
        PIL.Image.fromarray(row_images[0], 'RGB').save('%s/frame%05d.png' % (temp_dir, row))

    return temp_dir

# %% [markdown]
# ## Generate Images
#
# ### Use Volume to interpolate between two seeds
# The next cell will take two seed values and do a linear interpolation of them using the volume from your audio. When the audio is silent, it will be the first seed you list. When it is at its loudest it will be the second. Everything in between will be an interpolated value.
#
# How long this takes is dependant on the length of audio you've chosen.

# %%
network_pkl = '/content/ffhq.pkl'
# The seeds below choose the two images that you will interpolate between,
# so I'm just picking two random numbers.
seeds=[np.random.randint(0, 10000),np.random.randint(0, 10000)]
truncation_value = 0.5

#you probably won't need to edit anything below this
_G, _D, Gs = pretrained_networks.load_networks(network_pkl)

Gs_kwargs = dnnlib.EasyDict()
Gs_kwargs.output_transform = dict(func=tflib.convert_images_to_uint8, nchw_to_nhwc=True)
Gs_kwargs.randomize_noise = False
Gs_syn_kwargs = dnnlib.EasyDict()
Gs_syn_kwargs.output_transform = dict(func=tflib.convert_images_to_uint8, nchw_to_nhwc=True)
Gs_syn_kwargs.randomize_noise = False
Gs_syn_kwargs.minibatch_size = 4
noise_vars = [var for name, var in Gs.components.synthesis.vars.items() if name.startswith('noise')]
w_avg = Gs.get_var('dlatent_avg')

def get_ws(n, frames, seed):
    filename = f'../ws_{n}_{frames}_{seed}.npy'
    if not os.path.exists(filename):
        src_ws = np.random.RandomState(seed).randn(n, 512)
        ws = np.empty((frames, 512))
        for i in range(512):
            x = np.linspace(0, 3*frames, 3*len(src_ws), endpoint=False)
            y = np.tile(src_ws[:, i], 3)
            x_ = np.linspace(0, 3*frames, 3*frames, endpoint=False)
            y_ = interp1d(x, y, kind='quadratic', fill_value='extrapolate')(x_)
            ws[:, i] = y_[frames:2*frames]
        np.save(filename, ws)
    else:
        ws = np.load(filename)
    return ws

def lerp(v0, v1, t):
    return v0*(1.0-t)+v1*t


ends = generate_zs_from_seeds(seeds,Gs)
ends_w = []

for e in range(len(ends)):
  ends_w.append(convertZtoW(ends[e],0.5))

vectors = []
for f in range(frames):
  vectors.append(lerp(ends_w[0],ends_w[1],audio[track_name][f]))

frame_dir = generate_images_in_w_space(vectors,truncation_value)
# Out:
# Generating image for step 0/180 ...
# Generating image for step 1/180 ...
# Generating image for step 2/180 ...
# Generating image for step 3/180 ...
# Generating image for step 4/180 ...
# Generating image for step 5/180 ...
# Generating image for step 6/180 ...
# Generating image for step 7/180 ...
# Generating image for step 8/180 ...
# Generating image for step 9/180 ...
# Generating image for step 10/180 ...
# Generating image for step 11/180 ...
# Generating image for step 12/180 ...
# Generating image for step 13/180 ...
# Generating image for step 14/180 ...
# Generating image for step 15/180 ...
# Generating image for step 16/180 ...
# Generating image for step 17/180 ...
# Generating image for step 18/180 ...
# Generating image for step 19/180 ...
# Generating image for step 20/180 ...
# Generating image for step 21/180 ...
# Generating image for step 22/180 ...
# Generating image for step 23/180 ...
# Generating image for step 24/180 ...
# Generating image for step 25/180 ...
# Generating image for step 26/180 ...
# Generating image for step 27/180 ...
# Generating image for step 28/180 ...
# Generating image for step 29/180 ...
# Generating image for step 30/180 ...
# Generating image for step 31/180 ...
# Generating image for step 32/180 ...
# Generating image for step 33/180 ...
# Generating image for step 34/180 ...
# Generating image for step 35/180 ...
# Generating image for step 36/180 ...
# Generating image for step 37/180 ...
# Generating image for step 38/180 ...
# Generating image for step 39/180 ...
# Generating image for step 40/180 ...
# Generating image for step 41/180 ...
# Generating image for step 42/180 ...
# Generating image for step 43/180 ...
# Generating image for step 44/180 ...
# Generating image for step 45/180 ...
# Generating image for step 46/180 ...
# Generating image for step 47/180 ...
# Generating image for step 48/180 ...
# Generating image for step 49/180 ...
# Generating image for step 50/180 ...
# Generating image for step 51/180 ...
# Generating image for step 52/180 ...
# Generating image for step 53/180 ...
# Generating image for step 54/180 ...
# Generating image for step 55/180 ...
# Generating image for step 56/180 ...
# Generating image for step 57/180 ...
# Generating image for step 58/180 ...
# Generating image for step 59/180 ...
# Generating image for step 60/180 ...
# Generating image for step 61/180 ...
# Generating image for step 62/180 ...
# Generating image for step 63/180 ...
# Generating image for step 64/180 ...
# Generating image for step 65/180 ...
# Generating image for step 66/180 ...
# Generating image for step 67/180 ...
# Generating image for step 68/180 ...
# Generating image for step 69/180 ...
# Generating image for step 70/180 ...
# Generating image for step 71/180 ...
# Generating image for step 72/180 ...
# Generating image for step 73/180 ...
# Generating image for step 74/180 ...
# Generating image for step 75/180 ...
# Generating image for step 76/180 ...
# Generating image for step 77/180 ...
# Generating image for step 78/180 ...
# Generating image for step 79/180 ...
# Generating image for step 80/180 ...
# Generating image for step 81/180 ...
# Generating image for step 82/180 ...
# Generating image for step 83/180 ...
# Generating image for step 84/180 ...
# Generating image for step 85/180 ...
# Generating image for step 86/180 ...
# Generating image for step 87/180 ...
# Generating image for step 88/180 ...
# Generating image for step 89/180 ...
# Generating image for step 90/180 ...
# Generating image for step 91/180 ...
# Generating image for step 92/180 ...
# Generating image for step 93/180 ...
# Generating image for step 94/180 ...
# Generating image for step 95/180 ...
# Generating image for step 96/180 ...
# Generating image for step 97/180 ...
# Generating image for step 98/180 ...
# Generating image for step 99/180 ...
# Generating image for step 100/180 ...
# Generating image for step 101/180 ...
# Generating image for step 102/180 ...
# Generating image for step 103/180 ...
# Generating image for step 104/180 ...
# Generating image for step 105/180 ...
# Generating image for step 106/180 ...
# Generating image for step 107/180 ...
# Generating image for step 108/180 ...
# Generating image for step 109/180 ...
# Generating image for step 110/180 ...
# Generating image for step 111/180 ...
# Generating image for step 112/180 ...
# Generating image for step 113/180 ...
# Generating image for step 114/180 ...
# Generating image for step 115/180 ...
# Generating image for step 116/180 ...
# Generating image for step 117/180 ...
# Generating image for step 118/180 ...
# Generating image for step 119/180 ...
# Generating image for step 120/180 ...
# Generating image for step 121/180 ...
# Generating image for step 122/180 ...
# Generating image for step 123/180 ...
# Generating image for step 124/180 ...
# Generating image for step 125/180 ...
# Generating image for step 126/180 ...
# Generating image for step 127/180 ...
# Generating image for step 128/180 ...
# Generating image for step 129/180 ...
# Generating image for step 130/180 ...
# Generating image for step 131/180 ...
# Generating image for step 132/180 ...
# Generating image for step 133/180 ...
# Generating image for step 134/180 ...
# Generating image for step 135/180 ...
# Generating image for step 136/180 ...
# Generating image for step 137/180 ...
# Generating image for step 138/180 ...
# Generating image for step 139/180 ...
# Generating image for step 140/180 ...
# Generating image for step 141/180 ...
# Generating image for step 142/180 ...
# Generating image for step 143/180 ...
# Generating image for step 144/180 ...
# Generating image for step 145/180 ...
# Generating image for step 146/180 ...
# Generating image for step 147/180 ...
# Generating image for step 148/180 ...
# Generating image for step 149/180 ...
# Generating image for step 150/180 ...
# Generating image for step 151/180 ...
# Generating image for step 152/180 ...
# Generating image for step 153/180 ...
# Generating image for step 154/180 ...
# Generating image for step 155/180 ...
# Generating image for step 156/180 ...
# Generating image for step 157/180 ...
# Generating image for step 158/180 ...
# Generating image for step 159/180 ...
# Generating image for step 160/180 ...
# Generating image for step 161/180 ...
# Generating image for step 162/180 ...
# Generating image for step 163/180 ...
# Generating image for step 164/180 ...
# Generating image for step 165/180 ...
# Generating image for step 166/180 ...
# Generating image for step 167/180 ...
# Generating image for step 168/180 ...
# Generating image for step 169/180 ...
# Generating image for step 170/180 ...
# Generating image for step 171/180 ...
# Generating image for step 172/180 ...
# Generating image for step 173/180 ...
# Generating image for step 174/180 ...
# Generating image for step 175/180 ...
# Generating image for step 176/180 ...
# Generating image for step 177/180 ...
# Generating image for step 178/180 ...
# Generating image for step 179/180 ...

# %% [markdown]
# ### Combine the frames into a video and add the audio track back to it
#
# There’s probably a cleaner way to do this all in moviepy but I’m being lazy.

# %%
# !ffmpeg -r 60 -i /content/stylegan2/{frame_dir}/frame%05d.png -vcodec libx264 -pix_fmt yuv420p /content/sound-react-volume.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/stylegan2/frames492379/frame%05d.png':
#   Duration: 00:00:07.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# File '/content/sound-react-volume.mp4' already exists. Overwrite ? [y/N] y
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5620e5451e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5620e5451e00] profile High, level 4.0
# [libx264 @ 0x5620e5451e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/sound-react-volume.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# Past duration 0.999992 too large
#     Last message repeated 44 times
# Past duration 0.999992 too large
#     Last message repeated 19 times
# Past duration 0.999992 too large
#     Last message repeated 24 times
# Past duration 0.999992 too large
#     Last message repeated 19 times
# Past duration 0.999992 too large
#     Last message repeated 19 times
# Past duration 0.999992 too large
#     Last message repeated 23 times
# Past duration 0.999992 too large
#     Last message repeated 14 times
# Past duration 0.999992 too large
#     Last message repeated 9 times
# frame=  181 fps= 40 q=-1.0 Lsize=     896kB time=00:00:02.96 bitrate=2474.4kbits/s dup=1 drop=0 speed=0.656x
# video:893kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.313086%
# [libx264 @ 0x5620e5451e00] frame I:3     Avg QP:22.03  size: 90378
# [libx264 @ 0x5620e5451e00] frame P:73    Avg QP:21.20  size:  3424
# [libx264 @ 0x5620e5451e00] frame B:105   Avg QP:28.67  size:  3743
# [libx264 @ 0x5620e5451e00] consecutive B-frames: 15.5% 17.7% 11.6% 55.2%
# [libx264 @ 0x5620e5451e00] mb I  I16..4:  8.4% 75.8% 15.7%
# [libx264 @ 0x5620e5451e00] mb P  I16..4:  0.6%  2.3%  0.4%  P16..4: 11.2%  1.1%  1.2%  0.0%  0.0%    skip:83.3%
# [libx264 @ 0x5620e5451e00] mb B  I16..4:  1.1%  2.7%  0.5%  B16..8:  6.3%  1.0%  0.1%  direct: 3.7%  skip:84.5%  L0:29.2% L1:68.4% BI: 2.4%
# [libx264 @ 0x5620e5451e00] 8x8 transform intra:68.6% inter:78.8%
# [libx264 @ 0x5620e5451e00] coded y,uvDC,uvAC intra: 65.8% 62.5% 19.4% inter: 4.4% 8.0% 0.0%
# [libx264 @ 0x5620e5451e00] i16 v,h,dc,p: 14% 24%  8% 54%
# [libx264 @ 0x5620e5451e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 15% 19%  8%  8%  8%  9%  9% 10%
# [libx264 @ 0x5620e5451e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 15% 14% 10% 11%  9% 10%  8%  8%
# [libx264 @ 0x5620e5451e00] i8c dc,h,v,p: 55% 19% 18%  9%
# [libx264 @ 0x5620e5451e00] Weighted P-Frames: Y:2.7% UV:2.7%
# [libx264 @ 0x5620e5451e00] ref P L0: 68.5%  9.9%  9.8% 11.7%  0.1%
# [libx264 @ 0x5620e5451e00] ref B L0: 91.4%  8.2%  0.4%
# [libx264 @ 0x5620e5451e00] ref B L1: 94.5%  5.5%
# [libx264 @ 0x5620e5451e00] kb/s:2424.07

# %%
mp4_filename = '../volume-lerp-test.mp4'
# video_clip = moviepy.editor.VideoClip(render_frame, duration=duration)
video_clip = moviepy.editor.VideoFileClip('/content/sound-react-volume.mp4')
audio_clip_i = moviepy.editor.AudioFileClip(filename)
video_clip = video_clip.set_audio(audio_clip_i)
video_clip.write_videofile(mp4_filename, fps=fps, codec='libx264', audio_codec='aac', bitrate='8M')
# Out:
# [MoviePy] >>>> Building video ../volume-lerp-test.mp4
# [MoviePy] Writing audio in volume-lerp-testTEMP_MPY_wvf_snd.mp4
# 100%|██████████| 67/67 [00:00<00:00, 563.67it/s]
# [MoviePy] Done.
# [MoviePy] Writing video ../volume-lerp-test.mp4
# 100%|██████████| 182/182 [00:03<00:00, 50.90it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ../volume-lerp-test.mp4

# %% [markdown]
# ### Use Volume to control truncation
# In this example, we’ll use almost the same technique but use volume to change the truncation value.
#
# It’s helpful that both interpolation and truncation are essentially 0.0 to 1.0. This matches the volume signal’s output, but what if we wanted to alter it?
#
# **This bit takes about twice as long as the previous generation...**

# %%
seeds=[10]

seed_z = generate_zs_from_seeds(seeds,Gs)

Gs_kwargs = dnnlib.EasyDict()
Gs_kwargs.output_transform = dict(func=tflib.convert_images_to_uint8, nchw_to_nhwc=True)
Gs_kwargs.randomize_noise = False

rnd = np.random.RandomState(seeds[0])

temp_dir = '%s-trunc_frames%06d'%(track_name,int(1000000*random.random()))
os.system('mkdir %s'%temp_dir)

for f in range(frames):
  print('Rendering frame %d/%d ...' % (f,frames))
  Gs_kwargs.truncation_psi = audio[track_name][f]
  tflib.set_vars({var: rnd.randn(*var.shape.as_list()) for var in noise_vars}) # [height, width]
  images = Gs.run(seed_z[0], None, **Gs_kwargs) # [minibatch, height, width, channel]
  PIL.Image.fromarray(images[0], 'RGB').save('%s/frame%05d.png' % (temp_dir,f))
# Out:
# Rendering frame 0/180 ...
# Rendering frame 1/180 ...
# Rendering frame 2/180 ...
# Rendering frame 3/180 ...
# Rendering frame 4/180 ...
# Rendering frame 5/180 ...
# Rendering frame 6/180 ...
# Rendering frame 7/180 ...
# Rendering frame 8/180 ...
# Rendering frame 9/180 ...
# Rendering frame 10/180 ...
# Rendering frame 11/180 ...
# Rendering frame 12/180 ...
# Rendering frame 13/180 ...
# Rendering frame 14/180 ...
# Rendering frame 15/180 ...
# Rendering frame 16/180 ...
# Rendering frame 17/180 ...
# Rendering frame 18/180 ...
# Rendering frame 19/180 ...
# Rendering frame 20/180 ...
# Rendering frame 21/180 ...
# Rendering frame 22/180 ...
# Rendering frame 23/180 ...
# Rendering frame 24/180 ...
# Rendering frame 25/180 ...
# Rendering frame 26/180 ...
# Rendering frame 27/180 ...
# Rendering frame 28/180 ...
# Rendering frame 29/180 ...
# Rendering frame 30/180 ...
# Rendering frame 31/180 ...
# Rendering frame 32/180 ...
# Rendering frame 33/180 ...
# Rendering frame 34/180 ...
# Rendering frame 35/180 ...
# Rendering frame 36/180 ...
# Rendering frame 37/180 ...
# Rendering frame 38/180 ...
# Rendering frame 39/180 ...
# Rendering frame 40/180 ...
# Rendering frame 41/180 ...
# Rendering frame 42/180 ...
# Rendering frame 43/180 ...
# Rendering frame 44/180 ...
# Rendering frame 45/180 ...
# Rendering frame 46/180 ...
# Rendering frame 47/180 ...
# Rendering frame 48/180 ...
# Rendering frame 49/180 ...
# Rendering frame 50/180 ...
# Rendering frame 51/180 ...
# Rendering frame 52/180 ...
# Rendering frame 53/180 ...
# Rendering frame 54/180 ...
# Rendering frame 55/180 ...
# Rendering frame 56/180 ...
# Rendering frame 57/180 ...
# Rendering frame 58/180 ...
# Rendering frame 59/180 ...
# Rendering frame 60/180 ...
# Rendering frame 61/180 ...
# Rendering frame 62/180 ...
# Rendering frame 63/180 ...
# Rendering frame 64/180 ...
# Rendering frame 65/180 ...
# Rendering frame 66/180 ...
# Rendering frame 67/180 ...
# Rendering frame 68/180 ...
# Rendering frame 69/180 ...
# Rendering frame 70/180 ...
# Rendering frame 71/180 ...
# Rendering frame 72/180 ...
# Rendering frame 73/180 ...
# Rendering frame 74/180 ...
# Rendering frame 75/180 ...
# Rendering frame 76/180 ...
# Rendering frame 77/180 ...
# Rendering frame 78/180 ...
# Rendering frame 79/180 ...
# Rendering frame 80/180 ...
# Rendering frame 81/180 ...
# Rendering frame 82/180 ...
# Rendering frame 83/180 ...
# Rendering frame 84/180 ...
# Rendering frame 85/180 ...
# Rendering frame 86/180 ...
# Rendering frame 87/180 ...
# Rendering frame 88/180 ...
# Rendering frame 89/180 ...
# Rendering frame 90/180 ...
# Rendering frame 91/180 ...
# Rendering frame 92/180 ...
# Rendering frame 93/180 ...
# Rendering frame 94/180 ...
# Rendering frame 95/180 ...
# Rendering frame 96/180 ...
# Rendering frame 97/180 ...
# Rendering frame 98/180 ...
# Rendering frame 99/180 ...
# Rendering frame 100/180 ...
# Rendering frame 101/180 ...
# Rendering frame 102/180 ...
# Rendering frame 103/180 ...
# Rendering frame 104/180 ...
# Rendering frame 105/180 ...
# Rendering frame 106/180 ...
# Rendering frame 107/180 ...
# Rendering frame 108/180 ...
# Rendering frame 109/180 ...
# Rendering frame 110/180 ...
# Rendering frame 111/180 ...
# Rendering frame 112/180 ...
# Rendering frame 113/180 ...
# Rendering frame 114/180 ...
# Rendering frame 115/180 ...
# Rendering frame 116/180 ...
# Rendering frame 117/180 ...
# Rendering frame 118/180 ...
# Rendering frame 119/180 ...
# Rendering frame 120/180 ...
# Rendering frame 121/180 ...
# Rendering frame 122/180 ...
# Rendering frame 123/180 ...
# Rendering frame 124/180 ...
# Rendering frame 125/180 ...
# Rendering frame 126/180 ...
# Rendering frame 127/180 ...
# Rendering frame 128/180 ...
# Rendering frame 129/180 ...
# Rendering frame 130/180 ...
# Rendering frame 131/180 ...
# Rendering frame 132/180 ...
# Rendering frame 133/180 ...
# Rendering frame 134/180 ...
# Rendering frame 135/180 ...
# Rendering frame 136/180 ...
# Rendering frame 137/180 ...
# Rendering frame 138/180 ...
# Rendering frame 139/180 ...
# Rendering frame 140/180 ...
# Rendering frame 141/180 ...
# Rendering frame 142/180 ...
# Rendering frame 143/180 ...
# Rendering frame 144/180 ...
# Rendering frame 145/180 ...
# Rendering frame 146/180 ...
# Rendering frame 147/180 ...
# Rendering frame 148/180 ...
# Rendering frame 149/180 ...
# Rendering frame 150/180 ...
# Rendering frame 151/180 ...
# Rendering frame 152/180 ...
# Rendering frame 153/180 ...
# Rendering frame 154/180 ...
# Rendering frame 155/180 ...
# Rendering frame 156/180 ...
# Rendering frame 157/180 ...
# Rendering frame 158/180 ...
# Rendering frame 159/180 ...
# Rendering frame 160/180 ...
# Rendering frame 161/180 ...
# Rendering frame 162/180 ...
# Rendering frame 163/180 ...
# Rendering frame 164/180 ...
# Rendering frame 165/180 ...
# Rendering frame 166/180 ...
# Rendering frame 167/180 ...
# Rendering frame 168/180 ...
# Rendering frame 169/180 ...
# Rendering frame 170/180 ...
# Rendering frame 171/180 ...
# Rendering frame 172/180 ...
# Rendering frame 173/180 ...
# Rendering frame 174/180 ...
# Rendering frame 175/180 ...
# Rendering frame 176/180 ...
# Rendering frame 177/180 ...
# Rendering frame 178/180 ...
# Rendering frame 179/180 ...

# %%
# !ffmpeg -r 60 -i /content/stylegan2/{temp_dir}/frame%05d.png -vcodec libx264 -pix_fmt yuv420p /content/sound-truncation-volume.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/stylegan2/one-man-clap-trunc_frames875923/frame%05d.png':
#   Duration: 00:00:07.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x561cfa9e3e00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x561cfa9e3e00] profile High, level 4.0
# [libx264 @ 0x561cfa9e3e00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/sound-truncation-volume.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# Past duration 0.999992 too large
#     Last message repeated 44 times
# Past duration 0.999992 too large
#     Last message repeated 11 times
# Past duration 0.999992 too large
#     Last message repeated 8 times
# Past duration 0.999992 too large
#     Last message repeated 13 times
# Past duration 0.999992 too large
#     Last message repeated 9 times
# Past duration 0.999992 too large
#     Last message repeated 8 times
# Past duration 0.999992 too large
#     Last message repeated 9 times
# Past duration 0.999992 too large
#     Last message repeated 10 times
# Past duration 0.999992 too large
#     Last message repeated 7 times
# Past duration 0.999992 too large
#     Last message repeated 10 times
# Past duration 0.999992 too large
#     Last message repeated 8 times
# Past duration 0.999992 too large
#     Last message repeated 8 times
# Past duration 0.999992 too large
#     Last message repeated 10 times
# Past duration 0.999992 too large
#     Last message repeated 8 times
# Past duration 0.999992 too large
#     Last message repeated 1 times
# frame=  181 fps= 19 q=-1.0 Lsize=    3172kB time=00:00:02.96 bitrate=8759.1kbits/s dup=1 drop=0 speed=0.304x
# video:3170kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.062473%
# [libx264 @ 0x561cfa9e3e00] frame I:2     Avg QP:25.90  size: 29020
# [libx264 @ 0x561cfa9e3e00] frame P:143   Avg QP:28.48  size: 18425
# [libx264 @ 0x561cfa9e3e00] frame B:36    Avg QP:28.69  size: 15354
# [libx264 @ 0x561cfa9e3e00] consecutive B-frames: 72.9%  1.1%  1.7% 24.3%
# [libx264 @ 0x561cfa9e3e00] mb I  I16..4: 18.7% 72.0%  9.3%
# [libx264 @ 0x561cfa9e3e00] mb P  I16..4:  6.4% 20.3%  2.7%  P16..4: 45.6%  8.9%  4.5%  0.0%  0.0%    skip:11.5%
# [libx264 @ 0x561cfa9e3e00] mb B  I16..4:  2.8% 10.4%  1.1%  B16..8: 46.2%  9.4%  1.5%  direct: 3.5%  skip:25.3%  L0:51.1% L1:47.3% BI: 1.6%
# [libx264 @ 0x561cfa9e3e00] 8x8 transform intra:69.7% inter:86.8%
# [libx264 @ 0x561cfa9e3e00] coded y,uvDC,uvAC intra: 54.2% 32.9% 1.4% inter: 26.7% 20.3% 0.0%
# [libx264 @ 0x561cfa9e3e00] i16 v,h,dc,p: 19% 16%  9% 56%
# [libx264 @ 0x561cfa9e3e00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13%  9% 18%  9% 12% 11% 10%  9%  8%
# [libx264 @ 0x561cfa9e3e00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 12% 14%  7% 18% 11% 12%  6%  4%
# [libx264 @ 0x561cfa9e3e00] i8c dc,h,v,p: 72% 11% 14%  2%
# [libx264 @ 0x561cfa9e3e00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x561cfa9e3e00] ref P L0: 38.2%  8.9% 30.1% 22.9%
# [libx264 @ 0x561cfa9e3e00] ref B L0: 60.4% 29.8%  9.8%
# [libx264 @ 0x561cfa9e3e00] ref B L1: 82.9% 17.1%
# [libx264 @ 0x561cfa9e3e00] kb/s:8606.90

# %%
mp4_filename = '../volume-trunc-test-v2.mp4'
# video_clip = moviepy.editor.VideoClip(render_frame, duration=duration)
video_clip = moviepy.editor.VideoFileClip('/content/sound-truncation-volume.mp4')
audio_clip_i = moviepy.editor.AudioFileClip(filename)
video_clip = video_clip.set_audio(audio_clip_i)
video_clip.write_videofile(mp4_filename, fps=fps, codec='libx264', audio_codec='aac', bitrate='8M')
# Out:
# [MoviePy] >>>> Building video ../volume-trunc-test-v2.mp4
# [MoviePy] Writing audio in volume-trunc-test-v2TEMP_MPY_wvf_snd.mp4
# 100%|██████████| 67/67 [00:00<00:00, 532.53it/s]
# [MoviePy] Done.
# [MoviePy] Writing video ../volume-trunc-test-v2.mp4
# 100%|██████████| 182/182 [00:06<00:00, 29.07it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ../volume-trunc-test-v2.mp4

# %%
seeds=[10]

seed_z = generate_zs_from_seeds(seeds,Gs)

Gs_kwargs = dnnlib.EasyDict()
Gs_kwargs.output_transform = dict(func=tflib.convert_images_to_uint8, nchw_to_nhwc=True)
Gs_kwargs.randomize_noise = False

rnd = np.random.RandomState(seeds[0])
temp_dir = '%s-trunc_frames%06d'%(track_name,int(1000000*random.random()))
os.system('mkdir %s'%temp_dir)

for f in range(frames):
  print('Rendering frame %d/%d ...' % (f,frames))

  #edit the next line to alter the volume signal
  # new_truncation_value = audio[track_name][f]*2 #multiply by 2 (0.0 to 2.0 for volume signal/truncation value now)
  new_truncation_value = (audio[track_name][f]-0.5)*2 #(-1.0 to 1.0 for volume signal/truncation value now)

  Gs_kwargs.truncation_psi = new_truncation_value
  tflib.set_vars({var: rnd.randn(*var.shape.as_list()) for var in noise_vars}) # [height, width]
  images = Gs.run(seed_z[0], None, **Gs_kwargs) # [minibatch, height, width, channel]
  PIL.Image.fromarray(images[0], 'RGB').save('%s/frame%05d.png' % (temp_dir,f))
# Out:
# Rendering frame 0/180 ...
# Rendering frame 1/180 ...
# Rendering frame 2/180 ...
# Rendering frame 3/180 ...
# Rendering frame 4/180 ...
# Rendering frame 5/180 ...
# Rendering frame 6/180 ...
# Rendering frame 7/180 ...
# Rendering frame 8/180 ...
# Rendering frame 9/180 ...
# Rendering frame 10/180 ...
# Rendering frame 11/180 ...
# Rendering frame 12/180 ...
# Rendering frame 13/180 ...
# Rendering frame 14/180 ...
# Rendering frame 15/180 ...
# Rendering frame 16/180 ...
# Rendering frame 17/180 ...
# Rendering frame 18/180 ...
# Rendering frame 19/180 ...
# Rendering frame 20/180 ...
# Rendering frame 21/180 ...
# Rendering frame 22/180 ...
# Rendering frame 23/180 ...
# Rendering frame 24/180 ...
# Rendering frame 25/180 ...
# Rendering frame 26/180 ...
# Rendering frame 27/180 ...
# Rendering frame 28/180 ...
# Rendering frame 29/180 ...
# Rendering frame 30/180 ...
# Rendering frame 31/180 ...
# Rendering frame 32/180 ...
# Rendering frame 33/180 ...
# Rendering frame 34/180 ...
# Rendering frame 35/180 ...
# Rendering frame 36/180 ...
# Rendering frame 37/180 ...
# Rendering frame 38/180 ...
# Rendering frame 39/180 ...
# Rendering frame 40/180 ...
# Rendering frame 41/180 ...
# Rendering frame 42/180 ...
# Rendering frame 43/180 ...
# Rendering frame 44/180 ...
# Rendering frame 45/180 ...
# Rendering frame 46/180 ...
# Rendering frame 47/180 ...
# Rendering frame 48/180 ...
# Rendering frame 49/180 ...
# Rendering frame 50/180 ...
# Rendering frame 51/180 ...
# Rendering frame 52/180 ...
# Rendering frame 53/180 ...
# Rendering frame 54/180 ...
# Rendering frame 55/180 ...
# Rendering frame 56/180 ...
# Rendering frame 57/180 ...
# Rendering frame 58/180 ...
# Rendering frame 59/180 ...
# Rendering frame 60/180 ...
# Rendering frame 61/180 ...
# Rendering frame 62/180 ...
# Rendering frame 63/180 ...
# Rendering frame 64/180 ...
# Rendering frame 65/180 ...
# Rendering frame 66/180 ...
# Rendering frame 67/180 ...
# Rendering frame 68/180 ...
# Rendering frame 69/180 ...
# Rendering frame 70/180 ...
# Rendering frame 71/180 ...
# Rendering frame 72/180 ...
# Rendering frame 73/180 ...
# Rendering frame 74/180 ...
# Rendering frame 75/180 ...
# Rendering frame 76/180 ...
# Rendering frame 77/180 ...
# Rendering frame 78/180 ...
# Rendering frame 79/180 ...
# Rendering frame 80/180 ...
# Rendering frame 81/180 ...
# Rendering frame 82/180 ...
# Rendering frame 83/180 ...
# Rendering frame 84/180 ...
# Rendering frame 85/180 ...
# Rendering frame 86/180 ...
# Rendering frame 87/180 ...
# Rendering frame 88/180 ...
# Rendering frame 89/180 ...
# Rendering frame 90/180 ...
# Rendering frame 91/180 ...
# Rendering frame 92/180 ...
# Rendering frame 93/180 ...
# Rendering frame 94/180 ...
# Rendering frame 95/180 ...
# Rendering frame 96/180 ...
# Rendering frame 97/180 ...
# Rendering frame 98/180 ...
# Rendering frame 99/180 ...
# Rendering frame 100/180 ...
# Rendering frame 101/180 ...
# Rendering frame 102/180 ...
# Rendering frame 103/180 ...
# Rendering frame 104/180 ...
# Rendering frame 105/180 ...
# Rendering frame 106/180 ...
# Rendering frame 107/180 ...
# Rendering frame 108/180 ...
# Rendering frame 109/180 ...
# Rendering frame 110/180 ...
# Rendering frame 111/180 ...
# Rendering frame 112/180 ...
# Rendering frame 113/180 ...
# Rendering frame 114/180 ...
# Rendering frame 115/180 ...
# Rendering frame 116/180 ...
# Rendering frame 117/180 ...
# Rendering frame 118/180 ...
# Rendering frame 119/180 ...
# Rendering frame 120/180 ...
# Rendering frame 121/180 ...
# Rendering frame 122/180 ...
# Rendering frame 123/180 ...
# Rendering frame 124/180 ...
# Rendering frame 125/180 ...
# Rendering frame 126/180 ...
# Rendering frame 127/180 ...
# Rendering frame 128/180 ...
# Rendering frame 129/180 ...
# Rendering frame 130/180 ...
# Rendering frame 131/180 ...
# Rendering frame 132/180 ...
# Rendering frame 133/180 ...
# Rendering frame 134/180 ...
# Rendering frame 135/180 ...
# Rendering frame 136/180 ...
# Rendering frame 137/180 ...
# Rendering frame 138/180 ...
# Rendering frame 139/180 ...
# Rendering frame 140/180 ...
# Rendering frame 141/180 ...
# Rendering frame 142/180 ...
# Rendering frame 143/180 ...
# Rendering frame 144/180 ...
# Rendering frame 145/180 ...
# Rendering frame 146/180 ...
# Rendering frame 147/180 ...
# Rendering frame 148/180 ...
# Rendering frame 149/180 ...
# Rendering frame 150/180 ...
# Rendering frame 151/180 ...
# Rendering frame 152/180 ...
# Rendering frame 153/180 ...
# Rendering frame 154/180 ...
# Rendering frame 155/180 ...
# Rendering frame 156/180 ...
# Rendering frame 157/180 ...
# Rendering frame 158/180 ...
# Rendering frame 159/180 ...
# Rendering frame 160/180 ...
# Rendering frame 161/180 ...
# Rendering frame 162/180 ...
# Rendering frame 163/180 ...
# Rendering frame 164/180 ...
# Rendering frame 165/180 ...
# Rendering frame 166/180 ...
# Rendering frame 167/180 ...
# Rendering frame 168/180 ...
# Rendering frame 169/180 ...
# Rendering frame 170/180 ...
# Rendering frame 171/180 ...
# Rendering frame 172/180 ...
# Rendering frame 173/180 ...
# Rendering frame 174/180 ...
# Rendering frame 175/180 ...
# Rendering frame 176/180 ...
# Rendering frame 177/180 ...
# Rendering frame 178/180 ...
# Rendering frame 179/180 ...

# %%
# !ffmpeg -r 60 -i /content/stylegan2/{temp_dir}/frame%05d.png -vcodec libx264 -pix_fmt yuv420p /content/sound-truncation-volume-2.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.2 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/stylegan2/one-man-clap-trunc_frames220977/frame%05d.png':
#   Duration: 00:00:07.20, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x562196fbbe00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x562196fbbe00] profile High, level 4.0
# [libx264 @ 0x562196fbbe00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/sound-truncation-volume-2.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# Past duration 0.999992 too large
#     Last message repeated 44 times
# Past duration 0.999992 too large
#     Last message repeated 10 times
# Past duration 0.999992 too large
#     Last message repeated 7 times
# Past duration 0.999992 too large
#     Last message repeated 7 times
# Past duration 0.999992 too large
#     Last message repeated 8 times
# Past duration 0.999992 too large
#     Last message repeated 7 times
# Past duration 0.999992 too large
#     Last message repeated 10 times
# Past duration 0.999992 too large
#     Last message repeated 7 times
# Past duration 0.999992 too large
#     Last message repeated 8 times
# Past duration 0.999992 too large
#     Last message repeated 6 times
# Past duration 0.999992 too large
#     Last message repeated 9 times
# Past duration 0.999992 too large
#     Last message repeated 8 times
# Past duration 0.999992 too large
#     Last message repeated 7 times
# Past duration 0.999992 too large
#     Last message repeated 8 times
# Past duration 0.999992 too large
#     Last message repeated 9 times
# Past duration 0.999992 too large
#     Last message repeated 8 times
# frame=  181 fps= 16 q=-1.0 Lsize=    4231kB time=00:00:02.96 bitrate=11683.7kbits/s dup=1 drop=0 speed=0.263x
# video:4230kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.041006%
# [libx264 @ 0x562196fbbe00] frame I:1     Avg QP:27.63  size: 33404
# [libx264 @ 0x562196fbbe00] frame P:168   Avg QP:29.56  size: 24115
# [libx264 @ 0x562196fbbe00] frame B:12    Avg QP:30.11  size: 20472
# [libx264 @ 0x562196fbbe00] consecutive B-frames: 90.6%  1.1%  1.7%  6.6%
# [libx264 @ 0x562196fbbe00] mb I  I16..4: 15.5% 76.0%  8.6%
# [libx264 @ 0x562196fbbe00] mb P  I16..4:  7.4% 29.0%  3.8%  P16..4: 40.7%  9.9%  4.0%  0.0%  0.0%    skip: 5.1%
# [libx264 @ 0x562196fbbe00] mb B  I16..4:  2.7% 13.7%  2.1%  B16..8: 41.5% 11.1%  1.5%  direct: 6.4%  skip:20.9%  L0:50.0% L1:48.1% BI: 1.9%
# [libx264 @ 0x562196fbbe00] 8x8 transform intra:72.2% inter:86.5%
# [libx264 @ 0x562196fbbe00] coded y,uvDC,uvAC intra: 61.1% 48.8% 4.1% inter: 34.6% 32.7% 0.1%
# [libx264 @ 0x562196fbbe00] i16 v,h,dc,p: 14% 20%  8% 59%
# [libx264 @ 0x562196fbbe00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 11% 15%  8% 12% 12% 10% 10%  9%
# [libx264 @ 0x562196fbbe00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 11% 12%  7% 17% 15% 10%  6%  5%
# [libx264 @ 0x562196fbbe00] i8c dc,h,v,p: 61% 17% 13%  9%
# [libx264 @ 0x562196fbbe00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x562196fbbe00] ref P L0: 37.7%  9.0% 30.3% 23.0%
# [libx264 @ 0x562196fbbe00] ref B L0: 58.4% 33.4%  8.2%
# [libx264 @ 0x562196fbbe00] ref B L1: 87.3% 12.7%
# [libx264 @ 0x562196fbbe00] kb/s:11483.80

# %%
mp4_filename = '../volume-trunc-test-v3.mp4'
# video_clip = moviepy.editor.VideoClip(render_frame, duration=duration)
video_clip = moviepy.editor.VideoFileClip('/content/sound-truncation-volume-2.mp4')
audio_clip_i = moviepy.editor.AudioFileClip(filename)
video_clip = video_clip.set_audio(audio_clip_i)
video_clip.write_videofile(mp4_filename, fps=fps, codec='libx264', audio_codec='aac', bitrate='8M')
# Out:
# [MoviePy] >>>> Building video ../volume-trunc-test-v3.mp4
# [MoviePy] Writing audio in volume-trunc-test-v3TEMP_MPY_wvf_snd.mp4
# 100%|██████████| 67/67 [00:00<00:00, 507.93it/s]
# [MoviePy] Done.
# [MoviePy] Writing video ../volume-trunc-test-v3.mp4
# 100%|██████████| 182/182 [00:06<00:00, 28.95it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ../volume-trunc-test-v3.mp4

# %% [markdown]
# ## Using feature vectors
#
# Let’s look at an example using a feature vector. In this case we’ll just use the straight audio signal.
#
# Upload your feature vector to Colab and then reference it’s location with a variable.

# %%
network_pkl = "/content/ffhq.pkl"
_G, _D, Gs = pretrained_networks.load_networks(network_pkl)

Gs_kwargs = dnnlib.EasyDict()
Gs_kwargs.output_transform = dict(func=tflib.convert_images_to_uint8, nchw_to_nhwc=True)
Gs_kwargs.randomize_noise = False
Gs_syn_kwargs = dnnlib.EasyDict()
Gs_syn_kwargs.output_transform = dict(func=tflib.convert_images_to_uint8, nchw_to_nhwc=True)
Gs_syn_kwargs.randomize_noise = False
Gs_syn_kwargs.minibatch_size = 4
noise_vars = [var for name, var in Gs.components.synthesis.vars.items() if name.startswith('noise')]
w_avg = Gs.get_var('dlatent_avg')

def generate_mov(seed, truncation, direction_vec, scale, n_frames, out_name = 'out', noise_spec = None, loop=True):
  """Generates a mov moving back and forth along the chosen direction vector"""
  # Example of reading a generated set of images, and storing as MP4.
  # %mkdir out
  movieName = f'out/{out_name}.mp4'
  offset = -10
  step = 20 / n_frames
  imgs = []
  for i in range(n_frames):
    print(f'{i} / {n_frames}')
    
    
    batch_size = 1
    all_seeds = [seed] * batch_size
    all_z = np.stack([np.random.RandomState(seed).randn(*Gs.input_shape[1:]) for seed in all_seeds]) # [minibatch, component]
    all_w = Gs.components.mapping.run(all_z, None) # [minibatch, layer, component]
    if truncation != 1:
        w_avg = Gs.get_var('dlatent_avg')
        all_w = w_avg + (all_w - w_avg) * truncation # [minibatch, layer, component]
    all_w += direction_vec * offset * scale
    all_images = Gs.components.synthesis.run(all_w, **Gs_syn_kwargs)
    #save image and display
    final_im = PIL.Image.fromarray(np.median(all_images, axis=0).astype(np.uint8))
    imgs.append(final_im)
    #increase offset
    offset += step
  if loop:
    imgs += imgs[::-1]
  with imageio.get_writer(movieName, mode='I') as writer:
    for image in log_progress(list(imgs), name = "Creating animation"):
        writer.append_data(np.array(image))
# Out:
# Setting up TensorFlow plugin "fused_bias_act.cu": Preprocessing... Compiling... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Preprocessing... Compiling... Loading... Done.

# %%
seed = 10 # starting seed (will appear at 0.5)
truncation = 0.7
feature = '/content/profile-c2.npy'
feature_range = 2 # feature_range maps the range of change in features 
scale = 1 # scale multiples the strength of the feature (1 is prob fine)

#-------------------

Gs_kwargs = dnnlib.EasyDict()
Gs_kwargs.output_transform = dict(func=tflib.convert_images_to_uint8, nchw_to_nhwc=True)
Gs_kwargs.randomize_noise = False
if truncation is not None:
  Gs_kwargs.truncation_psi = truncation
tflib.set_vars({var: rnd.randn(*var.shape.as_list()) for var in noise_vars}) # [height, width]
w_avg = Gs.get_var('dlatent_avg')

# get starting z and w
rnd = np.random.RandomState(seed)
z = rnd.randn(1, *Gs.input_shape[1:])
w = Gs.components.mapping.run(z, None)

# make dir
feature_name=os.path.basename(feature)[:-4] 
dir = '%s_%s_range%02d_seed%05d'%(track_name,feature_name,feature_range,seed)
os.system('mkdir %s'%dir)

# setup
feature_vec = np.load(feature)
min_range = -feature_range
max_range = feature_range
offset = min_range #start value

#generate frames
for f in range(frames):
  print('Rendering frame %d/%d ...' % (f,frames))

  if truncation != 1:
    w = w_avg + (w - w_avg) * truncation # [minibatch, layer, component]
  
  w += feature_vec * offset * scale

  #save image and display
  image = Gs.components.synthesis.run(w, **Gs_syn_kwargs)
  PIL.Image.fromarray(image[0],'RGB').save('%s/frame%05d.png' % (dir,f))
  
  #increase offset
  offset = lerp( min_range,max_range,audio[track_name][f] )
# Out:
# Rendering frame 0/346 ...
# Rendering frame 1/346 ...
# Rendering frame 2/346 ...
# Rendering frame 3/346 ...
# Rendering frame 4/346 ...
# Rendering frame 5/346 ...
# Rendering frame 6/346 ...
# Rendering frame 7/346 ...
# Rendering frame 8/346 ...
# Rendering frame 9/346 ...
# Rendering frame 10/346 ...
# Rendering frame 11/346 ...
# Rendering frame 12/346 ...
# Rendering frame 13/346 ...
# Rendering frame 14/346 ...
# Rendering frame 15/346 ...
# Rendering frame 16/346 ...
# Rendering frame 17/346 ...
# Rendering frame 18/346 ...
# Rendering frame 19/346 ...
# Rendering frame 20/346 ...
# Rendering frame 21/346 ...
# Rendering frame 22/346 ...
# Rendering frame 23/346 ...
# Rendering frame 24/346 ...
# Rendering frame 25/346 ...
# Rendering frame 26/346 ...
# Rendering frame 27/346 ...
# Rendering frame 28/346 ...
# Rendering frame 29/346 ...
# Rendering frame 30/346 ...
# Rendering frame 31/346 ...
# Rendering frame 32/346 ...
# Rendering frame 33/346 ...
# Rendering frame 34/346 ...
# Rendering frame 35/346 ...
# Rendering frame 36/346 ...
# Rendering frame 37/346 ...
# Rendering frame 38/346 ...
# Rendering frame 39/346 ...
# Rendering frame 40/346 ...
# Rendering frame 41/346 ...
# Rendering frame 42/346 ...
# Rendering frame 43/346 ...
# Rendering frame 44/346 ...
# Rendering frame 45/346 ...
# Rendering frame 46/346 ...
# Rendering frame 47/346 ...
# Rendering frame 48/346 ...
# Rendering frame 49/346 ...
# Rendering frame 50/346 ...
# Rendering frame 51/346 ...
# Rendering frame 52/346 ...
# Rendering frame 53/346 ...
# Rendering frame 54/346 ...
# Rendering frame 55/346 ...
# Rendering frame 56/346 ...
# Rendering frame 57/346 ...
# Rendering frame 58/346 ...
# Rendering frame 59/346 ...
# Rendering frame 60/346 ...
# Rendering frame 61/346 ...
# Rendering frame 62/346 ...
# Rendering frame 63/346 ...
# Rendering frame 64/346 ...
# Rendering frame 65/346 ...
# Rendering frame 66/346 ...
# Rendering frame 67/346 ...
# Rendering frame 68/346 ...
# Rendering frame 69/346 ...
# Rendering frame 70/346 ...
# Rendering frame 71/346 ...
# Rendering frame 72/346 ...
# Rendering frame 73/346 ...
# Rendering frame 74/346 ...
# Rendering frame 75/346 ...
# Rendering frame 76/346 ...
# Rendering frame 77/346 ...
# Rendering frame 78/346 ...
# Rendering frame 79/346 ...
# Rendering frame 80/346 ...
# Rendering frame 81/346 ...
# Rendering frame 82/346 ...
# Rendering frame 83/346 ...
# Rendering frame 84/346 ...
# Rendering frame 85/346 ...
# Rendering frame 86/346 ...
# Rendering frame 87/346 ...
# Rendering frame 88/346 ...
# Rendering frame 89/346 ...
# Rendering frame 90/346 ...
# Rendering frame 91/346 ...
# Rendering frame 92/346 ...
# Rendering frame 93/346 ...
# Rendering frame 94/346 ...
# Rendering frame 95/346 ...
# Rendering frame 96/346 ...
# Rendering frame 97/346 ...
# Rendering frame 98/346 ...
# Rendering frame 99/346 ...
# Rendering frame 100/346 ...
# Rendering frame 101/346 ...
# Rendering frame 102/346 ...
# Rendering frame 103/346 ...
# Rendering frame 104/346 ...
# Rendering frame 105/346 ...
# Rendering frame 106/346 ...
# Rendering frame 107/346 ...
# Rendering frame 108/346 ...
# Rendering frame 109/346 ...
# Rendering frame 110/346 ...
# Rendering frame 111/346 ...
# Rendering frame 112/346 ...
# Rendering frame 113/346 ...
# Rendering frame 114/346 ...
# Rendering frame 115/346 ...
# Rendering frame 116/346 ...
# Rendering frame 117/346 ...
# Rendering frame 118/346 ...
# Rendering frame 119/346 ...
# Rendering frame 120/346 ...
# Rendering frame 121/346 ...
# Rendering frame 122/346 ...
# Rendering frame 123/346 ...
# Rendering frame 124/346 ...
# Rendering frame 125/346 ...
# Rendering frame 126/346 ...
# Rendering frame 127/346 ...
# Rendering frame 128/346 ...
# Rendering frame 129/346 ...
# Rendering frame 130/346 ...
# Rendering frame 131/346 ...
# Rendering frame 132/346 ...
# Rendering frame 133/346 ...
# Rendering frame 134/346 ...
# Rendering frame 135/346 ...
# Rendering frame 136/346 ...
# Rendering frame 137/346 ...
# Rendering frame 138/346 ...
# Rendering frame 139/346 ...
# Rendering frame 140/346 ...
# Rendering frame 141/346 ...
# Rendering frame 142/346 ...
# Rendering frame 143/346 ...
# Rendering frame 144/346 ...
# Rendering frame 145/346 ...
# Rendering frame 146/346 ...
# Rendering frame 147/346 ...
# Rendering frame 148/346 ...
# Rendering frame 149/346 ...
# Rendering frame 150/346 ...
# Rendering frame 151/346 ...
# Rendering frame 152/346 ...
# Rendering frame 153/346 ...
# Rendering frame 154/346 ...
# Rendering frame 155/346 ...
# Rendering frame 156/346 ...
# Rendering frame 157/346 ...
# Rendering frame 158/346 ...
# Rendering frame 159/346 ...
# Rendering frame 160/346 ...
# Rendering frame 161/346 ...
# Rendering frame 162/346 ...
# Rendering frame 163/346 ...
# Rendering frame 164/346 ...
# Rendering frame 165/346 ...
# Rendering frame 166/346 ...
# Rendering frame 167/346 ...
# Rendering frame 168/346 ...
# Rendering frame 169/346 ...
# Rendering frame 170/346 ...
# Rendering frame 171/346 ...
# Rendering frame 172/346 ...
# Rendering frame 173/346 ...
# Rendering frame 174/346 ...
# Rendering frame 175/346 ...
# Rendering frame 176/346 ...
# Rendering frame 177/346 ...
# Rendering frame 178/346 ...
# Rendering frame 179/346 ...
# Rendering frame 180/346 ...
# Rendering frame 181/346 ...
# Rendering frame 182/346 ...
# Rendering frame 183/346 ...
# Rendering frame 184/346 ...
# Rendering frame 185/346 ...
# Rendering frame 186/346 ...
# Rendering frame 187/346 ...
# Rendering frame 188/346 ...
# Rendering frame 189/346 ...
# Rendering frame 190/346 ...
# Rendering frame 191/346 ...
# Rendering frame 192/346 ...
# Rendering frame 193/346 ...
# Rendering frame 194/346 ...
# Rendering frame 195/346 ...
# Rendering frame 196/346 ...
# Rendering frame 197/346 ...
# Rendering frame 198/346 ...
# Rendering frame 199/346 ...
# Rendering frame 200/346 ...
# Rendering frame 201/346 ...
# Rendering frame 202/346 ...
# Rendering frame 203/346 ...
# Rendering frame 204/346 ...
# Rendering frame 205/346 ...
# Rendering frame 206/346 ...
# Rendering frame 207/346 ...
# Rendering frame 208/346 ...
# Rendering frame 209/346 ...
# Rendering frame 210/346 ...
# Rendering frame 211/346 ...
# Rendering frame 212/346 ...
# Rendering frame 213/346 ...
# Rendering frame 214/346 ...
# Rendering frame 215/346 ...
# Rendering frame 216/346 ...
# Rendering frame 217/346 ...
# Rendering frame 218/346 ...
# Rendering frame 219/346 ...
# Rendering frame 220/346 ...
# Rendering frame 221/346 ...
# Rendering frame 222/346 ...
# Rendering frame 223/346 ...
# Rendering frame 224/346 ...
# Rendering frame 225/346 ...
# Rendering frame 226/346 ...
# Rendering frame 227/346 ...
# Rendering frame 228/346 ...
# Rendering frame 229/346 ...
# Rendering frame 230/346 ...
# Rendering frame 231/346 ...
# Rendering frame 232/346 ...
# Rendering frame 233/346 ...
# Rendering frame 234/346 ...
# Rendering frame 235/346 ...
# Rendering frame 236/346 ...
# Rendering frame 237/346 ...
# Rendering frame 238/346 ...
# Rendering frame 239/346 ...
# Rendering frame 240/346 ...
# Rendering frame 241/346 ...
# Rendering frame 242/346 ...
# Rendering frame 243/346 ...
# Rendering frame 244/346 ...
# Rendering frame 245/346 ...
# Rendering frame 246/346 ...
# Rendering frame 247/346 ...
# Rendering frame 248/346 ...
# Rendering frame 249/346 ...
# Rendering frame 250/346 ...
# Rendering frame 251/346 ...
# Rendering frame 252/346 ...
# Rendering frame 253/346 ...
# Rendering frame 254/346 ...
# Rendering frame 255/346 ...
# Rendering frame 256/346 ...
# Rendering frame 257/346 ...
# Rendering frame 258/346 ...
# Rendering frame 259/346 ...
# Rendering frame 260/346 ...
# Rendering frame 261/346 ...
# Rendering frame 262/346 ...
# Rendering frame 263/346 ...
# Rendering frame 264/346 ...
# Rendering frame 265/346 ...
# Rendering frame 266/346 ...
# Rendering frame 267/346 ...
# Rendering frame 268/346 ...
# Rendering frame 269/346 ...
# Rendering frame 270/346 ...
# Rendering frame 271/346 ...
# Rendering frame 272/346 ...
# Rendering frame 273/346 ...
# Rendering frame 274/346 ...
# Rendering frame 275/346 ...
# Rendering frame 276/346 ...
# Rendering frame 277/346 ...
# Rendering frame 278/346 ...
# Rendering frame 279/346 ...
# Rendering frame 280/346 ...
# Rendering frame 281/346 ...
# Rendering frame 282/346 ...
# Rendering frame 283/346 ...
# Rendering frame 284/346 ...
# Rendering frame 285/346 ...
# Rendering frame 286/346 ...
# Rendering frame 287/346 ...
# Rendering frame 288/346 ...
# Rendering frame 289/346 ...
# Rendering frame 290/346 ...
# Rendering frame 291/346 ...
# Rendering frame 292/346 ...
# Rendering frame 293/346 ...
# Rendering frame 294/346 ...
# Rendering frame 295/346 ...
# Rendering frame 296/346 ...
# Rendering frame 297/346 ...
# Rendering frame 298/346 ...
# Rendering frame 299/346 ...
# Rendering frame 300/346 ...
# Rendering frame 301/346 ...
# Rendering frame 302/346 ...
# Rendering frame 303/346 ...
# Rendering frame 304/346 ...
# Rendering frame 305/346 ...
# Rendering frame 306/346 ...
# Rendering frame 307/346 ...
# Rendering frame 308/346 ...
# Rendering frame 309/346 ...
# Rendering frame 310/346 ...
# Rendering frame 311/346 ...
# Rendering frame 312/346 ...
# Rendering frame 313/346 ...
# Rendering frame 314/346 ...
# Rendering frame 315/346 ...
# Rendering frame 316/346 ...
# Rendering frame 317/346 ...
# Rendering frame 318/346 ...
# Rendering frame 319/346 ...
# Rendering frame 320/346 ...
# Rendering frame 321/346 ...
# Rendering frame 322/346 ...
# Rendering frame 323/346 ...
# Rendering frame 324/346 ...
# Rendering frame 325/346 ...
# Rendering frame 326/346 ...
# Rendering frame 327/346 ...
# Rendering frame 328/346 ...
# Rendering frame 329/346 ...
# Rendering frame 330/346 ...
# Rendering frame 331/346 ...
# Rendering frame 332/346 ...
# Rendering frame 333/346 ...
# Rendering frame 334/346 ...
# Rendering frame 335/346 ...
# Rendering frame 336/346 ...
# Rendering frame 337/346 ...
# Rendering frame 338/346 ...
# Rendering frame 339/346 ...
# Rendering frame 340/346 ...
# Rendering frame 341/346 ...
# Rendering frame 342/346 ...
# Rendering frame 343/346 ...
# Rendering frame 344/346 ...
# Rendering frame 345/346 ...

# %%
# !ffmpeg -r 60 -i /content/stylegan2/pleasureisallmine_01-stereo_profile-c2_range02_seed00010/frame%05d.png -vcodec libx264 -pix_fmt yuv420p /content/sound-feature-volume-range2.mp4
# Out:
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.18.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, image2, from '/content/stylegan2/pleasureisallmine_01-stereo_profile-c2_range02_seed00010/frame%05d.png':
#   Duration: 00:00:13.84, start: 0.000000, bitrate: N/A
#     Stream #0:0: Video: png, rgb24(pc), 1024x1024, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55bcdd5bfe00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55bcdd5bfe00] profile High, level 4.0
# [libx264 @ 0x55bcdd5bfe00] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/sound-feature-volume-range2.mp4':
#   Metadata:
#     encoder         : Lavf57.83.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1024x1024, q=-1--1, 60 fps, 15360 tbn, 60 tbc
#     Metadata:
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# Past duration 0.999992 too large
#     Last message repeated 37 times
# Past duration 0.999992 too large
#     Last message repeated 8 times
# Past duration 0.999992 too large
#     Last message repeated 7 times
# Past duration 0.999992 too large
#     Last message repeated 14 times
# Past duration 0.999992 too large
#     Last message repeated 8 times
# Past duration 0.999992 too large
#     Last message repeated 9 times
# Past duration 0.999992 too large
#     Last message repeated 10 times
# Past duration 0.999992 too large
#     Last message repeated 10 times
# Past duration 0.999992 too large
#     Last message repeated 9 times
# Past duration 0.999992 too large
#     Last message repeated 13 times
# Past duration 0.999992 too large
#     Last message repeated 6 times
# Past duration 0.999992 too large
#     Last message repeated 10 times
# Past duration 0.999992 too large
#     Last message repeated 8 times
# Past duration 0.999992 too large
#     Last message repeated 11 times
# Past duration 0.999992 too large
#     Last message repeated 12 times
# Past duration 0.999992 too large
#     Last message repeated 11 times
# Past duration 0.999992 too large
#     Last message repeated 12 times
# Past duration 0.999992 too large
#     Last message repeated 10 times
# Past duration 0.999992 too large
#     Last message repeated 12 times
# Past duration 0.999992 too large
#     Last message repeated 10 times
# Past duration 0.999992 too large
#     Last message repeated 9 times
# Past duration 0.999992 too large
#     Last message repeated 14 times
# Past duration 0.999992 too large
#     Last message repeated 12 times
# Past duration 0.999992 too large
#     Last message repeated 11 times
# Past duration 0.999992 too large
#     Last message repeated 11 times
# Past duration 0.999992 too large
#     Last message repeated 11 times
# Past duration 0.999992 too large
#     Last message repeated 13 times
# Past duration 0.999992 too large
#     Last message repeated 9 times
# frame=  347 fps= 20 q=-1.0 Lsize=    2824kB time=00:00:05.73 bitrate=4035.2kbits/s dup=1 drop=0 speed=0.338x
# video:2819kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.164314%
# [libx264 @ 0x55bcdd5bfe00] frame I:4     Avg QP:26.45  size: 37478
# [libx264 @ 0x55bcdd5bfe00] frame P:117   Avg QP:26.07  size: 13615
# [libx264 @ 0x55bcdd5bfe00] frame B:226   Avg QP:28.91  size:  5060
# [libx264 @ 0x55bcdd5bfe00] consecutive B-frames:  9.2%  5.8% 18.2% 66.9%
# [libx264 @ 0x55bcdd5bfe00] mb I  I16..4: 11.8% 74.7% 13.4%
# [libx264 @ 0x55bcdd5bfe00] mb P  I16..4:  4.5% 12.4%  1.6%  P16..4: 34.6%  6.5%  4.0%  0.0%  0.0%    skip:36.5%
# [libx264 @ 0x55bcdd5bfe00] mb B  I16..4:  0.9%  2.0%  0.2%  B16..8: 26.1%  2.5%  0.5%  direct: 3.2%  skip:64.7%  L0:47.0% L1:49.1% BI: 3.9%
# [libx264 @ 0x55bcdd5bfe00] 8x8 transform intra:67.6% inter:81.3%
# [libx264 @ 0x55bcdd5bfe00] coded y,uvDC,uvAC intra: 51.9% 42.3% 3.2% inter: 13.5% 10.0% 0.0%
# [libx264 @ 0x55bcdd5bfe00] i16 v,h,dc,p: 24% 20% 11% 45%
# [libx264 @ 0x55bcdd5bfe00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18%  9% 17%  7% 11% 13%  8% 11%  6%
# [libx264 @ 0x55bcdd5bfe00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23%  9% 11%  7% 17% 13% 10%  8%  4%
# [libx264 @ 0x55bcdd5bfe00] i8c dc,h,v,p: 62% 13% 21%  4%
# [libx264 @ 0x55bcdd5bfe00] Weighted P-Frames: Y:29.9% UV:7.7%
# [libx264 @ 0x55bcdd5bfe00] ref P L0: 51.7% 22.0% 14.3%  5.5%  6.5%
# [libx264 @ 0x55bcdd5bfe00] ref B L0: 66.3% 22.9% 10.8%
# [libx264 @ 0x55bcdd5bfe00] ref B L1: 89.3% 10.7%
# [libx264 @ 0x55bcdd5bfe00] kb/s:3992.80

# %%
mp4_filename = '../volume-feature-test-range2.mp4'
# video_clip = moviepy.editor.VideoClip(render_frame, duration=duration)
video_clip = moviepy.editor.VideoFileClip('/content/sound-feature-volume-range2.mp4')
audio_clip_i = moviepy.editor.AudioFileClip('/content/stylegan2/pleasureisallmine_01-stereo.wav')
video_clip = video_clip.set_audio(audio_clip_i)
video_clip.write_videofile(mp4_filename, fps=fps, codec='libx264', audio_codec='aac', bitrate='8M')
# Out:
# [MoviePy] >>>> Building video ../volume-feature-test-range2.mp4
# [MoviePy] Writing audio in volume-feature-test-range2TEMP_MPY_wvf_snd.mp4
# 100%|██████████| 128/128 [00:00<00:00, 640.23it/s]
# [MoviePy] Done.
# [MoviePy] Writing video ../volume-feature-test-range2.mp4
# 100%|██████████| 347/347 [00:15<00:00, 22.54it/s]
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: ../volume-feature-test-range2.mp4
